# %%
import pandas as pd

# %%
path = 'C:/Users/Pascal/Desktop/'
fichier = 'youtube.xlsx'
pd.read_excel(path + fichier, headers)
# Out:
#                            Despacito[16]  \
# 0                       Shape of You[21]
# 1                      See You Again[22]
# 2                        Uptown Funk[29]
# 3                      Gangnam Style[31]
# 4                              Sorry[36]
# 5                              Sugar[37]
# 6                       Shake It Off[38]
# 7                               Roar[39]
# 8                           Bailando[40]
# 9                  Thinking Out Loud[41]
# 10                    Counting Stars[42]
# 11                        Dark Horse[43]
# 12                           Lean On[44]
# 13                             Hello[45]
# 14                       Blank Space[47]
# 15                          Chantaje[48]
# 16               All About That Bass[49]
# 17              Closer (Lyric video)[50]
# 18                        Let Her Go[51]
# 19         This Is What You Came For[53]
# 20                          Mi Gente[54]
# 21  Waka Waka (This Time for Africa)[55]
# ...
